# %% [markdown]
# ## Load Necessary Python Libraries

# %%
# !pip install pandas
# !pip install pandas_profiling

# %%
# !pip install matplotlib

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.25.2)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandas_profiling import ProfileReport # for data definitions
# could use missingno package to visualize missing values in columns?

# %% [markdown]
# ## Data Collection

# %% [markdown]
# Now I will load the p53 mutants raw data file from 2010 and inspect the dataset structure.

# %%
filepath = "../data/K9_MODIFIED_data_v2.csv" 
k9_file = pd.read_csv(filepath, low_memory=False)

# %%
print(k9_file.head())
# Out:
#                   C1      C2      C3      C4      C5      C6      C7     C8  \
# 0              a119e  -0.161  -0.014   0.002  -0.036  -0.033  -0.093  0.025
# 1        a119e_l125p  -0.158  -0.002  -0.012  -0.025  -0.012  -0.106  0.013
# 2  a119e_r283k_a353v       ?       ?       ?       ?       ?       ?      ?
# 3              a161t  -0.169  -0.025   -0.01  -0.041  -0.045  -0.069  0.038
# 4              c135y  -0.183  -0.051  -0.023  -0.077  -0.092  -0.015  0.071
#
#       C9    C10  ...  C5401   C5402  C5403  C5404   C5405   C5406   C5407  \
# 0  0.005      0  ...  0.006   0.013  0.021   0.02   0.016  -0.011   0.003
# 1  0.005      0  ...  0.002  -0.008  0.007  0.015  -0.008  -0.011  -0.004
# 2      ?      ?  ...      ?       ?      ?      ?       ?       ?       ?
# 3  0.014  0.008  ...  0.019    0.01  0.025  0.025   0.021  -0.012   0.006
# 4  0.027   0.02  ...  0.051   0.012   0.05  0.038   0.051  -0.015   0.017
#
#    C5408   C5409     C5410
# 0   0.01  -0.007  inactive
# 1  0.013   0.005  inactive
# 2      ?       ?  inactive
# 3  0.016  -0.018  inactive
# 4  0.027  -0.049  inactive
#
# [5 rows x 5410 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# change the ?s to NaN to make them easier to drop
k9_labelled = k9_file.replace('?', np.NaN)

# %%
k9_labelled.head()
# Out:
#                   C1      C2      C3      C4      C5      C6      C7     C8  \
# 0              a119e  -0.161  -0.014   0.002  -0.036  -0.033  -0.093  0.025
# 1        a119e_l125p  -0.158  -0.002  -0.012  -0.025  -0.012  -0.106  0.013
# 2  a119e_r283k_a353v     NaN     NaN     NaN     NaN     NaN     NaN    NaN
# 3              a161t  -0.169  -0.025   -0.01  -0.041  -0.045  -0.069  0.038
# 4              c135y  -0.183  -0.051  -0.023  -0.077  -0.092  -0.015  0.071
#
#       C9    C10  ...  C5401   C5402  C5403  C5404   C5405   C5406   C5407  \
# 0  0.005      0  ...  0.006   0.013  0.021   0.02   0.016  -0.011   0.003
# 1  0.005      0  ...  0.002  -0.008  0.007  0.015  -0.008  -0.011  -0.004
# 2    NaN    NaN  ...    NaN     NaN    NaN    NaN     NaN     NaN     NaN
# 3  0.014  0.008  ...  0.019    0.01  0.025  0.025   0.021  -0.012   0.006
# 4  0.027   0.02  ...  0.051   0.012   0.05  0.038   0.051  -0.015   0.017
#
#    C5408   C5409     C5410
# 0   0.01  -0.007  inactive
# 1  0.013   0.005  inactive
# 2    NaN     NaN  inactive
# 3  0.016  -0.018  inactive
# 4  0.027  -0.049  inactive
#
# [5 rows x 5410 columns]

# %%
# check for rows that are all NaN
k9_NaNs = k9_labelled[k9_labelled.isna().any(axis=1)]
k9_NaNs.head()
# these rows can be dropped
# Out:
#                           C1   C2   C3   C4   C5   C6   C7   C8   C9  C10  \
# 2          a119e_r283k_a353v  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16   c141y_d228a_n235k_n239m  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 187              g245s_a161r  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 189              g245s_a161t  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 191              g245s_a161w  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      ...   C5401   C5402   C5403   C5404   C5405   C5406   C5407  C5408  \
# 2    ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN    NaN
# 16   ...  -0.018  -0.014  -0.013   0.006  -0.035  -0.012  -0.011  0.008
# 187  ...  -0.013  -0.011  -0.008   0.008  -0.028  -0.011  -0.009   0.01
# 189  ...   0.005   0.021   0.021   0.024   0.024   -0.01   0.007  0.009
# 191  ...  -0.029  -0.024  -0.025  -0.002  -0.055  -0.011  -0.016  0.007
#
#      C5409     C5410
# 2      NaN  inactive
# 16   0.026  inactive
# 187   0.02  inactive
# 189  -0.01  inactive
# 191   0.04  inactive
#
# [5 rows x 5410 columns]

# %%
k9_NaNs.shape # this means there are 181 rows to drop
# Out:
# (58, 5410)

# %%
# Now we're going to drop the rows with NaNs using df.dropna()
k9_temp = k9_labelled.dropna()
# Make sure to reset the index after dropping the NaN rows
k9_temp = k9_temp.reset_index(drop=True)

# %%
k9_temp.head()
# Out:
#             C1      C2      C3      C4      C5      C6      C7     C8     C9  \
# 0        a119e  -0.161  -0.014   0.002  -0.036  -0.033  -0.093  0.025  0.005
# 1  a119e_l125p  -0.158  -0.002  -0.012  -0.025  -0.012  -0.106  0.013  0.005
# 2        a161t  -0.169  -0.025   -0.01  -0.041  -0.045  -0.069  0.038  0.014
# 3        c135y  -0.183  -0.051  -0.023  -0.077  -0.092  -0.015  0.071  0.027
# 4  c135y_e285m  -0.154   0.005  -0.011  -0.013  -0.002  -0.115  0.005  0.002
#
#       C10  ...   C5401   C5402  C5403  C5404   C5405   C5406   C5407  C5408  \
# 0       0  ...   0.006   0.013  0.021   0.02   0.016  -0.011   0.003   0.01
# 1       0  ...   0.002  -0.008  0.007  0.015  -0.008  -0.011  -0.004  0.013
# 2   0.008  ...   0.019    0.01  0.025  0.025   0.021  -0.012   0.006  0.016
# 3    0.02  ...   0.051   0.012   0.05  0.038   0.051  -0.015   0.017  0.027
# 4  -0.003  ...  -0.011   0.012  0.009  0.003  -0.001   0.002  -0.006  0.009
#
#     C5409     C5410
# 0  -0.007  inactive
# 1   0.005  inactive
# 2  -0.018  inactive
# 3  -0.049  inactive
# 4   0.013  inactive
#
# [5 rows x 5410 columns]

# %%
# Here, we're going to double check that all NaNs were dropped
k9_temp.shape

# There are only 16591 rows left! This is the original 16772 minus the 181 rows that contained NaNs
# Out:
# (2637, 5410)

# %%
# save as a new file and then continue analysis on that file (k9_clean)
k9_temp.to_csv(r'../data/K9_clean_data.csv', index=False, header=True)

# %%
# !pip uninstall pandas-profiling
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Found existing installation: pandas-profiling 3.6.6
# Uninstalling pandas-profiling-3.6.6:
#   Would remove:
#     /opt/conda/bin/pandas_profiling
#     /opt/conda/lib/python3.10/site-packages/pandas_profiling-3.6.6.dist-info/*
#     /opt/conda/lib/python3.10/site-packages/pandas_profiling/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (2.2.0)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (3.8.2)
# Requirement already satisfied: pydantic>=2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (2.6.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (3.1.3)
# Requirement already satisfied: visions==0.7.5 in /opt/conda/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (0.7.5)
# Requirement already satisfied: numpy<1.26,>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (1.25.2)
# Requirement already satisfied: htmlmin==0.1.12 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (4.66.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (1.11)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (0.14.1)
# Requirement already satisfied: typeguard<5,>=4.1.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (4.1.5)
# Requirement already satisfied: imagehash==4.3.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (1.8.1)
# Requirement already satisfied: numba<0.59.0,>=0.56.0 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling==0.0.dev0) (0.58.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (1.5.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (10.2.0)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.10/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.10/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (3.2.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (0.2.0)
# WARNING: visions 0.7.5 does not provide the extra 'type-image-path'
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==0.0.dev0) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling==0.0.dev0) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling==0.0.dev0) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==0.0.dev0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==0.0.dev0) (2023.4)
# Requirement already satisfied: joblib>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==0.0.dev0) (1.3.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling==0.0.dev0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling==0.0.dev0) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling==0.0.dev0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (0.5.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.4->statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (1.16.0)
# Building wheels for collected packages: ydata-profiling
#   Building wheel for ydata-profiling (setup.py) ... done
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=357914 sha256=75e462f77dd4b287a54efc45753cf3cbc78e8fb3d7371aca83d07da114343467
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1mmot3ku/wheels/07/29/61/f533cc7cbd0a97efb2d1b94d3254a3e859a949367ba842577b
# Successfully built ydata-profiling
# ^C
# ERROR: Operation cancelled by user

# %% [markdown]
# ## Data Definition

# %%
# https://pandas-profiling.github.io/pandas-profiling/docs/master/rtd/pages/big_data.html
# "Disclaimer: This profiling report was generated using a sample of 100 rows of the original dataset."
import pandas as pd
from pandas_profiling import ProfileReport

encoding = 'unicode_escape'
sample_df = k9_temp.iloc[: , 1:]
sample = sample_df.sample(n=500)
profile = ProfileReport(sample, minimal=True, sort='None', html={'style':{'full_width': True}}, progress_bar=False, title='p53 Mutants Pandas Profiling Report')
