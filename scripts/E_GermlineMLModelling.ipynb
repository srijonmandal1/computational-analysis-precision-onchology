# %%
# -*- coding: utf-8 -*-

import csv
import numpy
from sklearn import datasets, svm, neighbors
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

def knnTest(data, top, runs, organ):
    # check if the topography is a certain location or not
    isOrgan = []
    for x in top:
        if (x ==organ):
            isOrgan.append(True)
        else:
            isOrgan.append(False)
    knn = neighbors.KNeighborsClassifier()
    avgVer = 0
    avgPredict = 0
    for i in range (0,runs):
    # take a sample for training, leave the rest for testing (cross-validation)
        data_train, data_test, top_train, top_test, organ_train, organ_test = train_test_split(data,top,isOrgan)
        knn.fit(data_train, organ_train)
        knn_ver = knn.predict(data_test)
        avgVer = avgVer + numpy.sum(knn_ver == organ_test)/len(organ_test)
        
        knn.fit(data_train, top_train)
        knn_predict = knn.predict(data_test)
        avgPredict = avgPredict + numpy.sum(knn_predict == top_test)/len(organ_test)


    avgVer = avgVer / runs
    avgPredict = avgPredict / runs
    print("Percentage Verification " + organ + ": ", avgVer)
    print("Percentage Prediction: ", avgPredict)

def clfTest(data, top, runs, organ):
    isOrgan = []
    breast = 0
    for x in top:
        if (x ==organ):
            isOrgan.append(True)
        else:
            isOrgan.append(False)
    avgVer = 0
    avgPredict = 0
    for i in range (0,runs):
    # take a sample for training, leave the rest for testing (cross-validation)
        data_train, data_test, top_train, top_test, organ_train, organ_test = train_test_split(data,top,isOrgan)
        clf = RandomForestClassifier(n_estimators=10, verbose = 3)
        clf = clf.fit(data_train, organ_train)
        clf_ver = clf.predict(data_test)
        clf = clf.fit(data_train, top_train)
        clf_predict = clf.predict(data_test)
        avgVer = avgVer + numpy.sum(clf_ver == organ_test)/len(organ_test)
        avgPredict = avgPredict + numpy.sum(clf_predict == top_test)/len(organ_test)


    avgVer = avgVer / runs
    avgPredict = avgPredict / runs
    print("Percentage Verification " + organ + ": ", avgVer)
    print("Percentage Prediction: ", avgPredict)
    
def clfTestProb(data, top, morph, runs):
    isOrgan = []
   
    
    for i in range (0,runs):
    # take a sample for training, leave the rest for testing (cross-validation)
        data_train, data_test, top_train, top_test, morph_train, morph_test = train_test_split(data,top, morph)
        clf = RandomForestClassifier(n_estimators=10, verbose=2)
       
        clf = clf.fit(data_train, top_train)
        top_class = clf.classes_
        clf_predict_top = clf.predict_proba(data_test)
        
        clf = clf.fit(data_train, morph_train)
        clf_predict_morph = clf.predict_proba(data_test)
        morph_class = clf.classes_
    strTop = []
    strMorph = []
    
    
    print("========== PRINTING PROBABLITIES ================")
    
    for prob in clf_predict_top:
        i = prob.tolist().index(max(prob))
        strTop.append( '{:.2f}'.format(max(prob)) + " " + str(top_class[i]))
    for prob in clf_predict_morph:
        i = prob.tolist().index(max(prob))
        strMorph.append( '{:.2f}'.format(max(prob)) + " " + str(morph_class[i]))
        
    for i,x in enumerate(strTop):
        print(x + " " + strMorph[i])
        
def svmTest(data, top, organ):
    isOrgan = []    
    for x in top:
        if (x == organ):
            isOrgan.append(True)
        else:
            isOrgan.append(False)    
    data_train, data_test, top_train, top_test, organ_train, organ_test = train_test_split(data,top,isOrgan)
    
    svc = svm.SVC(kernel='linear', verbose=2)
    svc.fit(data_train,organ_train)
    
    svc_predict = svc.predict(data_test)
    print(numpy.sum(svc_predict == organ_test)/len(organ_test))

def getData(filepath, germOrSomatic):
    with open(filepath) as f:
        next(f) # skip headers
    
        reader = csv.reader(f, delimiter="\t")
        data = list(reader)
        
        if (germOrSomatic == 'somatic'):
            # data fields    
            mut_type= [hash(item[7]) for item in data] # for somatic
            top = [item[30] for item in data]
            morph = [item[34] for item in data]
            loc = [item[2] for item in data]
            sex = [item[45] for item in data]
        else:
            mut_type = [hash(item[15]) for item in data]
            top = [item[39] for item in data]
            morph = [item[41] for item in data]
            loc = [item[10] for item in data]
            sex = [item[32] for item in data]
    # mapping the types
    for i,x in enumerate(sex):
        if (x == 'M'):
            sex[i] = 0
        else:
            sex[i] = 1
    # combine data fields
    data = [list(a) for a in zip(mut_type, loc, sex)]
    return (data, top, morph)
    
    
    
def main(): 
    data, top, morph= getData('germlineData.txt', 'germ')
    #svmTest(data, top, 'BREAST')
    clfTestProb(data, top, morph, 1)
    
main()
# Out:
# building tree 1 of 10
# building tree 2 of 10
# building tree 3 of 10
# building tree 4 of 10
# building tree 5 of 10
# building tree 6 of 10
# building tree 7 of 10
# building tree 8 of 10
# building tree 9 of 10
# building tree 10 of 10
# building tree 1 of 10
# building tree 2 of 10
# building tree 3 of 10
# building tree 4 of 10
# building tree 5 of 10
# building tree 6 of 10
# building tree 7 of 10
# building tree 8 of 10
# building tree 9 of 10
# building tree 10 of 10
# ========== PRINTING PROBABLITIES ================
# 0.40 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.32 Cancer, NOS
# 0.39 BREAST 0.54 Cancer, NOS
# 0.27 BREAST 0.50 Cancer, NOS
# 0.46 BONES, JOINTS AND ARTICULAR CARTILAGE OF LIMBS 0.42 Carcinoma, NOS
# 0.24 BRAIN 0.35 Cancer, NOS
# 0.68 BREAST 0.50 Cancer, NOS
# 0.25 BRAIN 0.36 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.25 BRAIN 0.36 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.25 BRAIN 0.36 Cancer, NOS
# 0.49 BREAST 0.55 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.46 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.41 Cancer, NOS
# 0.37 COLON 0.74 Cancer, NOS
# 0.50 COLON 0.40 Adenocarcinoma, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.30  0.47 Cancer, NOS
# 0.60 BRONCHUS AND LUNG 0.70 Carcinoma, NOS
# 0.53 BRAIN 0.56 Cancer, NOS
# 0.42 BREAST 0.52 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.53  0.53
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.70 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.70 Liposarcoma, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.38 BRAIN 0.53 Choroid plexus carcinoma (C71.5)
# 0.55 BREAST 0.52 Leukemia, NOS
# 0.50 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.65 Cancer, NOS
# 0.42 COLON 0.77 Cancer, NOS
# 0.53 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.45 Osteosarcoma, NOS (C40._, C41._)
# 0.46 BREAST 0.82 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.43 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.58 Cancer, NOS
# 0.65 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.47 Leydig cell tumor, malignant (C62._)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.44 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.38 Osteosarcoma, NOS (C40._, C41._)
# 0.80 HEAD&NECK, NOS 0.79 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.25 BRAIN 0.36 Cancer, NOS
# 0.37 BRAIN 0.32 Cancer, NOS
# 0.29 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.66 Cancer, NOS
# 0.53 BREAST 1.00 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.50 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.53
# 0.58 RECTUM 0.87 Cancer, NOS
# 0.76 BREAST 0.62 Cancer, NOS
# 0.24 UNKNOWN PRIMARY SITE 0.42 Cancer, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.51  0.56
# 0.31 BREAST 0.85 Cancer, NOS
# 0.68 BREAST 0.59 Cancer, NOS
# 0.54 BREAST 0.83 Cancer, NOS
# 0.75 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.65 Sarcoma, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.50 UTERUS, NOS 0.50 Cancer, NOS
# 0.70 PANCREAS 0.70 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.52 BREAST 0.69 Cancer, NOS
# 0.23 BREAST 0.53 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.37 BREAST 0.58 Cancer, NOS
# 0.47 BREAST 0.57 Cancer, NOS
# 0.58 RECTUM 0.87 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.32  0.38
# 0.69 BRAIN 0.62 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.28 BREAST 0.50 Cancer, NOS
# 0.50 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.48 Osteosarcoma, NOS (C40._, C41._)
# 0.33 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.25 Osteosarcoma, NOS (C40._, C41._)
# 0.29  0.34 Medulloblastoma, NOS (C71.6)
# 0.37 BREAST 0.41 Cancer, NOS
# 0.42 BREAST 0.42 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.38 BREAST 0.29 Cancer, NOS
# 0.70 ACCESSORY SINUSES 0.47 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 1.00 BREAST 0.92 Cancer, NOS
# 0.70 ACCESSORY SINUSES 0.47 Cancer, NOS
# 0.55 BRAIN 0.52 Cancer, NOS
# 0.38 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.44 Cancer, NOS
# 0.34 STOMACH 0.55 Cancer, NOS
# 0.66 BREAST 0.45 Carcinoma, NOS
# 0.43 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.60 Myxoid liposarcoma
# 0.38 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.46 Osteosarcoma, NOS (C40._, C41._)
# 0.46 BREAST 0.82 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.49 BRAIN 0.53 Cancer, NOS
# 1.00 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.70 Osteosarcoma, NOS (C40._, C41._)
# 0.22 BREAST 0.43 Cancer, NOS
# 0.48 BRAIN 0.40
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.24 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.28 Cancer, NOS
# 0.55 BRAIN 0.52 Cancer, NOS
# 0.37 CERVIX UTERI 0.46 Cancer, NOS
# 0.70 BREAST 0.90 Cancer, NOS
# 1.00 BREAST 0.92 Cancer, NOS
# 0.50 BRAIN 0.55 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.53 RECTUM 0.58 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.58 BRAIN 0.38 Cancer, NOS
# 0.65 BREAST 1.00 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 1.00 BREAST 0.58 Infiltrating ductular carcinoma (C50._)
# 0.29 STOMACH 0.44 Osteosarcoma, NOS (C40._, C41._)
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.66 BREAST 0.45 Carcinoma, NOS
# 0.25  0.36 Cancer, NOS
# 0.30 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.29 Cancer, NOS
# 0.54 BRAIN 1.00 Cancer, NOS
# 0.48 BREAST 0.66 Cancer, NOS
# 1.00 BREAST 0.79 Cancer, NOS
# 0.21 BRAIN 0.34 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.78 BRAIN 0.49 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.50 BREAST 0.57 Sarcoma, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.37  0.43
# 0.90 BREAST 0.78 Cancer, NOS
# 0.33 BREAST 0.56 Cancer, NOS
# 0.21 BRAIN 0.34 Cancer, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.55 ADRENAL GLAND 0.65
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.73 BREAST 1.00 Cancer, NOS
# 0.39 BREAST 0.54 Cancer, NOS
# 0.43 BREAST 0.66 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 1.00 BREAST 0.85 Cancer, NOS
# 0.79 BRAIN 0.56 Cancer, NOS
# 0.27 BREAST 0.50 Cancer, NOS
# 0.40 LIVER AND INTRAHEPATIC BILE DUCTS 0.72 Cancer, NOS
# 0.54 BRAIN 1.00 Cancer, NOS
# 0.68 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.32 Leukemia, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.27 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.35 Cancer, NOS
# 0.23 BREAST 0.53 Cancer, NOS
# 0.98 BREAST 0.80 Carcinoma, NOS
# 0.42 BRAIN 0.35 Fibrosarcoma, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.65 BREAST 1.00 Cancer, NOS
# 0.24 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.28 Cancer, NOS
# 0.22 BREAST 0.43 Cancer, NOS
# 0.47 BREAST 0.57 Cancer, NOS
# 0.21 BRAIN 0.34 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.22 BREAST 0.43 Cancer, NOS
# 0.49 BREAST 0.55 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.22 BREAST 0.37 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.29 BREAST 0.58 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.32 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.33
# 0.88 BREAST 0.90 Cancer, NOS
# 0.33 BRAIN 0.65 Cancer, NOS
# 0.33 BREAST 0.56 Cancer, NOS
# 0.80 PROSTATE GLAND 0.65 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.54  0.48
# 0.40 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.40 Basal cell carcinoma, NOS (C44._)
# 0.46 BREAST 0.48 Cancer, NOS
# 0.49 BREAST 0.55 Cancer, NOS
# 0.33 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.25 Osteosarcoma, NOS (C40._, C41._)
# 0.43 OTHER AND ILL-DEFINED SITES 0.31 Liposarcoma, NOS
# 0.25  0.38 Cancer, NOS
# 0.70 BREAST 0.71 Cancer, NOS
# 0.60 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.60 Therapy-related acute myeloid leukemia, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.53 BRAIN 0.56 Cancer, NOS
# 0.63 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Rhabdomyosarcoma, NOS
# 0.37 BREAST 1.00 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 1.00 UNKNOWN PRIMARY SITE 0.62 Cancer, NOS
# 0.58 BLADDER 0.51 Leukemia, NOS
# 0.37 BREAST 0.58 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.70 BRONCHUS AND LUNG 0.82 Cancer, NOS
# 0.41 BRAIN 0.32 Hodgkin lymphoma, NOS
# 0.42 BREAST 0.52 Cancer, NOS
# 0.31 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.51 Cancer, NOS
# 0.54 BREAST 0.87 Cancer, NOS
# 0.32 PROSTATE GLAND 0.86 Cancer, NOS
# 0.71 BREAST 0.66 Cancer, NOS
# 0.81 BRAIN 0.40 Tumor cells, NOS
# 0.48 BRAIN 0.40
# 0.34 OVARY 0.38 Cancer, NOS
# 0.59 BREAST 0.68 Cancer, NOS
# 0.37  0.46 Cancer, NOS
# 0.33 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.25 Osteosarcoma, NOS (C40._, C41._)
# 0.59 BREAST 0.68 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.21 BRAIN 0.34 Cancer, NOS
# 0.58 BRAIN 0.80 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.43 OTHER AND ILL-DEFINED SITES 0.31 Liposarcoma, NOS
# 0.59 BREAST 0.68 Cancer, NOS
# 0.38 BONES, JOINTS AND ARTICULAR CARTILAGE OF LIMBS 0.36 Osteosarcoma, NOS (C40._, C41._)
# 0.50 BREAST 0.76 Cancer, NOS
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.40 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.32 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.50 BREAST 0.51 Malignant melanoma, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.32  0.38
# 0.33 BREAST 0.32 Cancer, NOS
# 0.90 BREAST 1.00 Cancer, NOS
# 0.36 BREAST 0.18 Phyllodes tumor, malignant (C50._)
# 0.43 BREAST 0.66 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.65 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.47 Leydig cell tumor, malignant (C62._)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.32  0.38
# 0.29 ADRENAL GLAND 0.28
# 0.33 BREAST 0.32 Cancer, NOS
# 0.21 BRAIN 0.34 Cancer, NOS
# 0.39 BREAST 0.54 Cancer, NOS
# 0.27 BREAST 0.50 Cancer, NOS
# 0.17 BRONCHUS AND LUNG 0.32 Cancer, NOS
# 0.42 BRAIN 0.35 Fibrosarcoma, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.67 BREAST 0.70 Cancer, NOS
# 0.29 UNKNOWN PRIMARY SITE 0.46 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.37 UNKNOWN PRIMARY SITE 0.43 Sarcoma, NOS
# 0.65 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.47 Leydig cell tumor, malignant (C62._)
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.65 THYMUS 0.52 Thymoma, NOS (C37.9)
# 0.38 BRAIN 0.53 Choroid plexus carcinoma (C71.5)
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.70 PANCREAS 0.70 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.51 BREAST 0.91 Cancer, NOS
# 0.59 BREAST 0.39 Rhabdomyosarcoma, NOS
# 0.22 BREAST 0.43 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.41 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.46
# 0.59 BREAST 0.39 Rhabdomyosarcoma, NOS
# 0.70 UTERUS, NOS 0.80 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.80 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.80 Leukemia, NOS
# 0.39 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.67 Cancer, NOS
# 0.25  0.38 Cancer, NOS
# 0.31 BREAST 0.85 Cancer, NOS
# 0.60 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.72 Osteosarcoma, NOS (C40._, C41._)
# 0.22 BREAST 0.43 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.35 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.31 Osteosarcoma, NOS (C40._, C41._)
# 0.37 BREAST 0.41 Cancer, NOS
# 0.80 BREAST 0.90 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.50 BREAST 0.76 Cancer, NOS
# 0.68 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.74 Malignant fibrous histiocytoma
# 0.37 COLON 0.74 Cancer, NOS
# 0.90 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Sarcoma, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.72 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.50 Chondrosarcoma, NOS (C40._, C41._)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.59 BREAST 0.68 Cancer, NOS
# 0.43 BREAST 0.66 Cancer, NOS
# 0.50 LIVER AND INTRAHEPATIC BILE DUCTS 0.80 Cancer, NOS
# 0.42 BREAST 0.52 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.34 BRAIN 0.25 Osteosarcoma, NOS (C40._, C41._)
# 0.53 BREAST 0.45 Cancer, NOS
# 0.70  0.40
# 0.38 BREAST 0.29 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.44 BREAST 0.63 Cancer, NOS
# 0.42 COLON 0.77 Cancer, NOS
# 0.17 BRONCHUS AND LUNG 0.32 Cancer, NOS
# 0.70 TESTIS 0.46 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.29 PANCREAS 0.81 Cancer, NOS
# 0.53 BRAIN 0.56 Cancer, NOS
# 0.70  0.62
# 0.42 BREAST 0.52 Cancer, NOS
# 0.25  0.34 Sarcoma, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.38 BREAST 0.38 Cancer, NOS
# 0.67 BREAST 0.70 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.33 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.25 Osteosarcoma, NOS (C40._, C41._)
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.70  0.62
# 0.51 BREAST 0.91 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.65 BREAST 0.52 Stromal sarcoma, NOS
# 0.38 BRAIN 0.53 Choroid plexus carcinoma (C71.5)
# 0.25  0.36 Cancer, NOS
# 0.22 BREAST 0.43 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.51 HEART, MEDIASTINUM, AND PLEURA 0.47 Carcinoma, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.22 BREAST 0.37 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.66 BREAST 0.45 Carcinoma, NOS
# 0.82 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.79 Osteosarcoma, NOS (C40._, C41._)
# 0.73 BREAST 0.90 Cancer, NOS
# 0.81 BRAIN 0.40 Tumor cells, NOS
# 0.88 BREAST 0.90 Cancer, NOS
# 0.55 BRAIN 0.52 Cancer, NOS
# 0.35 BREAST 0.47 Sarcoma, NOS
# 0.44 BREAST 0.81 Cancer, NOS
# 0.42 BREAST 0.52 Cancer, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.21 BREAST 0.38 Cancer, NOS
# 0.39 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.67 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.50 BRAIN 0.55 Cancer, NOS
# 0.75 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.65 Sarcoma, NOS
# 0.51 BREAST 0.84 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.70 BREAST 0.71 Cancer, NOS
# 0.50  0.70
# 0.46 BREAST 0.67 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.65  0.76
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.43 BREAST 0.66 Cancer, NOS
# 0.42 COLON 0.77 Cancer, NOS
# 0.56 BREAST 0.43 Cancer, NOS
# 0.50 UTERUS, NOS 0.50 Cancer, NOS
# 0.53 BREAST 1.00 Cancer, NOS
# 1.00 UNKNOWN PRIMARY SITE 0.62 Cancer, NOS
# 0.42 COLON 0.77 Cancer, NOS
# 0.35 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.31 Osteosarcoma, NOS (C40._, C41._)
# 1.00 BREAST 0.90 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.59 BREAST 0.39 Rhabdomyosarcoma, NOS
# 0.86 BREAST 0.63 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.61 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.31 Sarcoma, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.65  0.60
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.42 COLON 0.77 Cancer, NOS
# 0.37 COLON 0.74 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.24 BRAIN 0.35 Cancer, NOS
# 0.29 BREAST 0.58 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.60 BRAIN 0.50 Glioblastoma, NOS (C71._)
# 0.39 BREAST 0.54 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.29  0.34 Medulloblastoma, NOS (C71.6)
# 0.29 ADRENAL GLAND 0.28
# 0.41 BRAIN 0.32 Hodgkin lymphoma, NOS
# 0.40 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.32 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.34 BRAIN 0.25 Osteosarcoma, NOS (C40._, C41._)
# 0.46 UNKNOWN PRIMARY SITE 0.48 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.65  0.76
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.37 BRAIN 0.32 Cancer, NOS
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.29 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.45 Osteosarcoma, NOS (C40._, C41._)
# 0.46 BREAST 0.48 Cancer, NOS
# 0.42 BREAST 0.52 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.86 BREAST 0.63 Cancer, NOS
# 0.64 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.72 Adrenal cortical carcinoma (C74.0)
# 0.85 BREAST 0.78 Cancer, NOS
# 0.43 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.58 Cancer, NOS
# 0.50 UNKNOWN PRIMARY SITE 0.78 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.62 BRAIN 0.60 Astrocytoma, anaplastic (C71._)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.71 COLON 0.80 Cancer, NOS
# 0.38 BREAST 0.29 Cancer, NOS
# 0.47 BREAST 0.57 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.29 STOMACH 0.44 Osteosarcoma, NOS (C40._, C41._)
# 0.38 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.44 Cancer, NOS
# 0.80  0.78
# 0.24 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.28 Cancer, NOS
# 0.68 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.32 Leukemia, NOS
# 0.33 BRAIN 0.65 Cancer, NOS
# 0.25  0.34 Sarcoma, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.40 BREAST 0.49 Cancer, NOS
# 0.27 LYMPH NODES 0.29 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.40 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.32 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.81 BRAIN 0.40 Tumor cells, NOS
# 0.72 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.50 Chondrosarcoma, NOS (C40._, C41._)
# 0.40 BREAST 0.49 Cancer, NOS
# 0.27 BREAST 0.50 Cancer, NOS
# 0.37 BREAST 0.58 Cancer, NOS
# 0.87 BREAST 0.78 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.33 BREAST 0.56 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.40 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.40 Basal cell carcinoma, NOS (C44._)
# 0.33 BREAST 0.32 Cancer, NOS
# 0.28 BRAIN 0.37 Choroid plexus carcinoma (C71.5)
# 0.58 BREAST 0.60 Carcinoma, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.15 BREAST 0.32 Cancer, NOS
# 0.17 BRONCHUS AND LUNG 0.32 Cancer, NOS
# 0.46 THYROID GLAND 0.65 Cancer, NOS
# 0.54 BRAIN 1.00 Cancer, NOS
# 0.90 BREAST 1.00 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.42 BREAST 0.52 Cancer, NOS
# 0.31 BREAST 0.85 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.32  0.38
# 0.52 BREAST 0.50
# 0.29 STOMACH 0.44 Osteosarcoma, NOS (C40._, C41._)
# 0.65 BREAST 1.00 Cancer, NOS
# 0.22 BREAST 0.43 Cancer, NOS
# 0.52 BREAST 0.50
# 0.37 BRAIN 0.56 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.24 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.28 Cancer, NOS
# 0.40 BREAST 0.49 Cancer, NOS
# 0.86 BRAIN 0.52 Cancer, NOS
# 0.59 BREAST 0.68 Cancer, NOS
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.40 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.32 Cancer, NOS
# 0.43 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.20 Adrenal cortical carcinoma (C74.0)
# 0.79 BRAIN 0.56 Cancer, NOS
# 0.40 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.35 Cancer, NOS
# 0.56 BREAST 0.43 Cancer, NOS
# 0.38 BREAST 0.29 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.29 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.45 Osteosarcoma, NOS (C40._, C41._)
# 0.43  0.39
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.33 BRAIN 0.65 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.38 BRAIN 0.53 Choroid plexus carcinoma (C71.5)
# 0.46 BREAST 0.82 Cancer, NOS
# 0.25  0.36 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.22 BREAST 0.37 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.36 BREAST 0.70 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.90 BREAST 0.82 Cancer, NOS
# 0.24 BRAIN 0.35 Cancer, NOS
# 0.60  0.80
# 0.37  0.46 Cancer, NOS
# 0.71 COLON 0.80 Cancer, NOS
# 0.57  0.75
# 0.46 BREAST 0.67 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.67 BREAST 0.70 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.80 UNKNOWN PRIMARY SITE 0.80 Cancer, NOS
# 0.29 BREAST 0.58 Cancer, NOS
# 0.68 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.74 Malignant fibrous histiocytoma
# 0.17 BRONCHUS AND LUNG 0.32 Cancer, NOS
# 0.29  0.34 Medulloblastoma, NOS (C71.6)
# 0.29 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.66 Cancer, NOS
# 0.48 VAGINA 0.50 Cancer, NOS
# 0.43 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.58 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.81 BRAIN 0.40 Tumor cells, NOS
# 0.25  0.38 Cancer, NOS
# 0.76 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.36 Malignant peripheral nerve sheath tumor
# 0.27 BREAST 0.50 Cancer, NOS
# 0.73 BREAST 0.33 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.55 BRAIN 0.52 Cancer, NOS
# 0.53 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.45 Osteosarcoma, NOS (C40._, C41._)
# 0.70 PANCREAS 0.70 Cancer, NOS
# 0.35 BREAST 0.43 Cancer, NOS
# 0.70 BONES, JOINTS AND ARTICULAR CARTILAGE OF LIMBS 0.50 Rhabdomyosarcoma, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.40  0.40
# 0.29 UNKNOWN PRIMARY SITE 0.46 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.60 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.60 Therapy-related acute myeloid leukemia, NOS
# 0.57 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.48 Carcinoma, NOS
# 0.27 BREAST 0.50 Cancer, NOS
# 0.40 LIVER AND INTRAHEPATIC BILE DUCTS 0.72 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.66 BREAST 0.84 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.68 BREAST 0.70 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 1.00 BREAST 0.95 Cancer, NOS
# 0.21 BRAIN 0.34 Cancer, NOS
# 1.00 BREAST 1.00 Cancer, NOS
# 0.48 LYMPH NODES 0.35
# 0.37 COLON 0.74 Cancer, NOS
# 0.62 BRAIN 0.52 Cancer, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.58 BRAIN 0.38 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.29 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.66 Cancer, NOS
# 0.54  0.48
# 0.25  0.36 Cancer, NOS
# 0.25  0.36 Cancer, NOS
# 1.00 BREAST 1.00 Cancer, NOS
# 0.82 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.52 Cancer, NOS
# 0.22 BREAST 0.37 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.38 BREAST 0.29 Cancer, NOS
# 0.65 BREAST 1.00 Cancer, NOS
# 0.50 OVARY 0.46 Serous cystadenocarcinoma, NOS (C56.9)
# 0.29 ADRENAL GLAND 0.28
# 0.50 HEAD&NECK, NOS 0.50 Carcinoma, NOS
# 0.53  0.53
# 0.15 BREAST 0.32 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.67 BREAST 0.70 Cancer, NOS
# 0.87 BREAST 0.78 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.46 BREAST 0.48 Cancer, NOS
# 0.30 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.25 Liposarcoma, NOS
# 0.72 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.80 Rhabdomyosarcoma, NOS
# 0.37 COLON 0.74 Cancer, NOS
# 0.46 UNKNOWN PRIMARY SITE 0.48 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.30 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.25 Liposarcoma, NOS
# 0.33 BREAST 0.56 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.27 BREAST 0.50 Cancer, NOS
# 0.64 BREAST 0.96 Cancer, NOS
# 0.46 BREAST 0.67 Cancer, NOS
# 0.25  0.38 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.80 UNKNOWN PRIMARY SITE 0.90 Cancer, NOS
# 0.56 BREAST 0.43 Cancer, NOS
# 0.52 BREAST 0.50
# 0.60 BREAST 0.60 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.24 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.28 Cancer, NOS
# 0.17 BRONCHUS AND LUNG 0.32 Cancer, NOS
# 0.33 BRAIN 0.65 Cancer, NOS
# 0.38 UNKNOWN PRIMARY SITE 0.55 Choroid plexus carcinoma (C71.5)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.79 BRAIN 0.56 Cancer, NOS
# 0.90 BREAST 1.00 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.37 BRAIN 0.32 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.46 BREAST 0.48 Cancer, NOS
# 0.67 BREAST 0.70 Cancer, NOS
# 0.40 BREAST 0.49 Cancer, NOS
# 0.15 BREAST 0.32 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.25  0.38 Cancer, NOS
# 0.60 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.72 Osteosarcoma, NOS (C40._, C41._)
# 0.30 BREAST 0.47 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.90 BREAST 0.78 Cancer, NOS
# 0.47 COLON 0.90 Cancer, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.17 BRONCHUS AND LUNG 0.32 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.22 BREAST 0.43 Cancer, NOS
# 0.70 PANCREAS 0.70 Cancer, NOS
# 0.61 BREAST 0.65 Cancer, NOS
# 0.29 BRAIN 0.52 Cancer, NOS
# 0.42 BREAST 0.77 Cancer, NOS
# 0.42 BRAIN 0.35 Fibrosarcoma, NOS
# 0.50 BREAST 0.90 Cancer, NOS
# 0.53 COLORECTUM, NOS 0.75 Cancer, NOS
# 0.85 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.50 Leiomyosarcoma, NOS
# 0.86 BREAST 0.63 Cancer, NOS
# 0.53 BREAST 0.43 Phyllodes tumor, malignant (C50._)
# 0.46 BREAST 0.48 Cancer, NOS
# 0.39 BREAST 0.54 Cancer, NOS
# 0.44 BREAST 0.63 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.58 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.56 Basal cell carcinoma, NOS (C44._)
# 0.71 BREAST 0.76 Cancer, NOS
# 0.85 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.50 Leiomyosarcoma, NOS
# 0.76 BREAST 0.62 Cancer, NOS
# 0.59 BREAST 0.60 Cancer, NOS
# 0.37 BREAST 0.58 Cancer, NOS
# 0.22 BREAST 0.37 Cancer, NOS
# 0.73 BREAST 0.33 Cancer, NOS
# 0.63 COLON 0.44 Cancer, NOS
# 0.59  0.55 Glioblastoma, NOS (C71._)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.52 BREAST 0.69 Cancer, NOS
# 0.54 BREAST 0.46 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.38 BREAST 0.29 Cancer, NOS
# 0.69 BRAIN 0.62 Cancer, NOS
# 0.54 BREAST 0.82 Cancer, NOS
# 0.73 BREAST 0.33 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.60 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.50 Chronic myeloid leukemia, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.22 BREAST 0.43 Cancer, NOS
# 0.58 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.56 Basal cell carcinoma, NOS (C44._)
# 0.38 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.46 Osteosarcoma, NOS (C40._, C41._)
# 0.37 BREAST 0.41 Cancer, NOS
# 0.59 BREAST 0.68 Cancer, NOS
# 0.80 LYMPH NODES 0.40 Malignant lymphoma, non-Hodgkin, NOS
# 0.79 BRAIN 0.56 Cancer, NOS
# 0.38 HEMATOPOIETIC AND RETICULOENDOTHELIAL SYSTEMS 0.44 Cancer, NOS
# 0.53 COLORECTUM, NOS 0.75 Cancer, NOS
# 0.29 ADRENAL GLAND 0.28
# 0.60 BRONCHUS AND LUNG 0.70 Carcinoma, NOS
# 0.57 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.48 Carcinoma, NOS
# 0.49 BRAIN 0.53 Cancer, NOS
# 0.37 CERVIX UTERI 0.46 Cancer, NOS
# 0.61 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.31 Sarcoma, NOS
# 0.20 STOMACH 0.61 Cancer, NOS
# 0.62  0.40
# 0.81 BRAIN 0.40 Tumor cells, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.80 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Leiomyosarcoma, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.61 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.31 Sarcoma, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.25  0.36 Cancer, NOS
# 0.29 STOMACH 0.44 Osteosarcoma, NOS (C40._, C41._)
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.46 BREAST 0.82 Cancer, NOS
# 0.71 BRAIN 0.55 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.85 BRAIN 0.44 Cancer, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.59  0.70 Ewing sarcoma
# 0.24 BREAST 0.63 Cancer, NOS
# 0.24 UNKNOWN PRIMARY SITE 0.42 Cancer, NOS
# 0.66 BREAST 0.84 Cancer, NOS
# 0.23 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.34 Cancer, NOS
# 0.71 BREAST 0.76 Cancer, NOS
# 0.54 UTERUS, NOS 0.86 Cancer, NOS
# 0.33 BRAIN 0.21 Cancer, NOS
# 1.00 COLON 0.71 Cancer, NOS
# 0.22 BREAST 0.37 Cancer, NOS
# 0.67 BREAST 0.70 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.29 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.57 Cancer, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.48 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.48 Rhabdomyosarcoma, NOS
# 0.47 COLON 0.90 Cancer, NOS
# 0.32 BREAST 0.35 Cancer, NOS
# 0.71 SKIN (excludes Skin of vulva, Skin of penis, Skin of scrotum ) 0.83 Basal cell carcinoma, NOS (C44._)
# 0.70 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.81 Sarcoma, NOS
# 0.35 ADRENAL GLAND 0.33 Cancer, NOS
# 0.90 BREAST 0.82 Cancer, NOS
# 0.37  0.29 Primitive neuroectodermal tumor, NOS (C71._)
# 1.00 BREAST 0.90 Cancer, NOS
# 0.33 BREAST 0.32 Cancer, NOS
# 0.29 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.66 Cancer, NOS
# 0.38 BONES, JOINTS AND ARTICULAR CARTILAGE OF OTHER AND UNSPECIFIED SITES 0.46 Osteosarcoma, NOS (C40._, C41._)
# 0.37 BREAST 0.41 Cancer, NOS
# 0.42 BRAIN 0.35 Fibrosarcoma, NOS
# 0.79 BRAIN 0.56 Cancer, NOS
# 0.64 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.72 Adrenal cortical carcinoma (C74.0)
# 0.80  0.53
# 0.29 ADRENAL GLAND 0.28
# 0.50 BREAST 0.51 Malignant melanoma, NOS
# 0.30 BREAST 0.47 Cancer, NOS
# 0.39 PROSTATE GLAND 0.52 Cancer, NOS
# 0.32 BRAIN 0.42 Cancer, NOS
# 0.37 BREAST 0.41 Cancer, NOS
# 0.90 CONNECTIVE, SUBCUTANEOUS AND OTHER SOFT TISSUES 0.80 Liposarcoma, NOS
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
